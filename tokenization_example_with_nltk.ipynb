# %%
corpus = '''hello Welcome to NLP Tutorials. Please do watch the entire course! to become expert in NLP'''

# %%
# tokenization 
## sentence --> paragraphs 
from nltk.tokenize import sent_tokenize
documents = sent_tokenize(corpus)

# %%
for sentence in documents:
    print(sentence)
# Out:
# hello Welcome to NLP Tutorials.
# Please do watch the entire course!
# to become expert in NLP

# %%
## Tokenization
## paragraph --> words
## sentence --> words
from nltk import word_tokenize
word_tokenize(corpus)

# %%
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(corpus)
# Out:
# ['hello',
#  'Welcome',
#  'to',
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP']

# %%
from nltk.tokenize import TreebankWordTokenizer

tokenizer = TreebankWordTokenizer()
# full stop will not be treated as the seprate word until it is the last full stop 

tokenizer.tokenize(corpus)
# Out:
# ['hello',
#  'Welcome',
#  'to',
#  'NLP',
#  'Tutorials.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP']

# %%
# Out:
# ['hello',
#  'Welcome',
#  'to',
#  'NLP',
#  'Tutorials.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP']
